# %% [markdown]
# # 2강 - 1번 문제
# - 정렬된 리스트에 새로운 요소 삽입
#
# 리스트 L 과 정수 x 가 인자로 주어질 때, 리스트 내의 올바른 위치에 x 를 삽입하여 그 결과 리스트를 반환하는 함수 solution 을 완성하세요.
#
# 인자로 주어지는 리스트 L 은 정수 원소들로 이루어져 있으며 크기에 따라 (오름차순으로) 정렬되어 있다고 가정합니다.
#
# 예를 들어, L = [20, 37, 58, 72, 91] 이고 x = 65 인 경우, 올바른 리턴 값은 [20, 37, 58, 65, 72, 91] 입니다.
#
# 힌트: 순환문을 이용하여 올바른 위치를 결정하고 insert() 메서드를 이용하여 삽입하는 것이 한 가지 방법입니다.
#
# 주의: 리스트 내에 존재하는 모든 원소들보다 작거나 모든 원소들보다 큰 정수가 주어지는 경우에 대해서도 올바르게 처리해야 합니다.

# %%
def solution(L, x):
    if L[0] > x:
        L.insert(0, x)
        return L
    elif L[len(L)-1] < x:
        # 리스트 끝에 요소 붙일 때는 원래 인덱스에서 길이 +1 됨!
        L.insert(len(L), x)
        return L
    for idx in range(0, len(L)-1):
        if L[idx] < x and L[idx+1] > x:
            L.insert(idx+1, x)
            return L

# %% [markdown]
# # 2강 - 2번 문제
#
# - 리스트에서 원소 찾아내기
#
# 인자로 주어지는 리스트 L 내에서, 또한 인자로 주어지는 원소 x 가 발견되는 모든 인덱스를 구하여 이 인덱스들로 이루어진 리스트를 반환하는 함수 solution 을 완성하세요.
#
# 리스트 L 은 정수들로 이루어져 있고 그 순서는 임의로 부여되어 있다고 가정하며, 동일한 원소가 반복하여 들어 있을 수 있습니다. 이 안에 정수 x 가 존재하면 그것들을 모두 발견하여 해당 인덱스들을 리스트로 만들어 반환하고, 만약 존재하지 않으면 하나의 원소로 이루어진 리스트 [-1] 를 반환하는 함수를 완성하세요.
#
# 예를 들어, L = [64, 72, 83, 72, 54] 이고 x = 72 인 경우의 올바른 리턴 값은 [1, 3] 입니다.
# 또 다른 예를 들어, L = [64, 72, 83, 72, 54] 이고 x = 83 인 경우의 올바른 리턴 값은 [2] 입니다.
# 마지막으로 또 다른 예를 들어, L = [64, 72, 83, 72, 54] 이고 x = 49 인 경우의 올바른 리턴 값은 [-1] 입니다.

# %%
# 내가 한 방법
def solution(L, x):
    idx_lst = []
    # x값이 L리스트 안에 없을 경우 
    if x not in L:
        idx_lst.append(-1)
        return idx_lst
    # 인덱스 초기화 
    start_at = -1
    # while 안에 try, except 구문 있게하자!
    while True:
        try:
            # 먼저 처음부터 끝(입력 안하면 디폴트로 끝 인덱스임) 사이의 인덱스 최솟값 반환
            idx = L.index(x, start_at+1)
            idx_lst.append(idx)
            # 찾은 최솟값 인덱스를 시작점으로 설정 => 이게 위로 L.index()가서 +1 하게 되면서 촤솟값 인덱스 다음 위치부터 시작
            start_at = idx
        except ValueError:
            break
    #while이랑 같은 indent위치에 있어야 그동안 요소들이 첨가된 idx_lst 한 번만 출력!
    return idx_lst

# %%
# 남이 푼 방법
def solution(L, x):
    if x in L:
        return [i for i, y in enumerate(L) if y == x]
    else:
        return [-1]

# %%
# 남이 푼 방법 - 해설
def solution(L, x):
    # x값이 L리스트 안에 있을 경우
    if x in L:
        # i는 L의 index, value는 L의 요소값들
        # value가 x값과 같을 때의 index를 리스트로 넣어라!
        return [i for i, value in enumerate(L) if value == x]
    
    # x값이 L리스트 안에 없는 경우
    else:
        return [-1]

# %% [markdown]
# # 3강 - 1번 문제
#
# - 이진 탐색 구현(``이진 탐색은 리스트 요소가 오름차순으로 정렬되어 있어야 함을 전제!``)
#
# 리스트 L 과, 그 안에서 찾으려 하는 원소 x 가 인자로 주어질 때, x 와 같은 값을 가지는 원소의 인덱스를 리턴하는 함수 solution() 을 완성하세요. 만약 리스트 L 안에 x 와 같은 값을 가지는 원소가 존재하지 않는 경우에는 -1 을 리턴합니다. 리스트 L 은 자연수 원소들로 이루어져 있으며, 크기 순으로 정렬되어 있다고 가정합니다. 또한, 동일한 원소는 두 번 이상 나타나지 않습니다.
#
# 예를 들어,
# L = [2, 3, 5, 6, 9, 11, 15]
# x = 6
# 의 인자들이 주어지면, L[3] == 6 이므로 3 을 리턴해야 합니다.
#
# 또 다른 예로,
# L = [2, 5, 7, 9, 11]
# x = 4
# 로 주어지면, 리스트 L 내에 4 의 원소가 존재하지 않으므로 -1 을 리턴해야 합니다.

# %%
# 내가 한 방법
def solution(L, x):
    # 인덱스 최솟값 할당
    lower = 0
    # 인덱스 최대값 할당
    upper = len(L) - 1
    
    # 인덱스 최솟값 > 인덱스 최댓값 될 때까지 반복
    # '=' 하나가 없어서 효율성 테스트에서 통과 못한다..(lower=upper index일 때도 while문 돌도록 하기)
    while lower <= upper:
        # 중간 인덱스 설정(이진 기준 설정)
        middle = (lower + upper) // 2
        
        # x값이 중간 인덱스랑 일치하는 값이면!
        if L[middle] == x:
            return middle
        # x값이 중간 인덱스보다 작을 때
        elif L[middle] > x:
            # 탐색할 인덱스 최댓값을 중간 인덱스-1로 하향 설정
            upper = middle - 1
        else:
            # x값이 중간 인덱스보다 클 때 탐색할 인덱스 최솟값을 중간 인덱스+1로 상향 설정
            lower = middle + 1
    # 위 while 조건을 위배할 때 즉, x값이 원소 안에 존재하지 않을 때 리턴
    return -1

# %% [markdown]
# # 4강 - 1번 문제(피보나치 수열)
#
# 인자로 0 또는 양의 정수인 x 가 주어질 때, Fibonacci 순열의 해당 값을 구하여 반환하는 함수 solution() 을 완성하세요.
#
# Fibonacci 순열은 아래와 같이 정의됩니다.
# F0 = 0
# F1 = 1
# Fn = Fn - 1 + Fn - 2, n >= 2

# %% [markdown]
# - F0 = solution(0) -> 0 반환
# - F1 = solution(1) -> 1 반환
# - F2 = solution(2) = solution(1) + solution(0) -> 1 + 0 = 1 반환
# - F3 = solution(3) = solution(2) + solution(1) = solution(1) + solution(0) + solution(1) = 1 + 0 + 1 = 2 반환
# - F4 = solution(4) = solution(3) + solution(2) = solution(2) + solution(1) + solution(1) + solution(0) = solution(1) + solution(0) + solution(1) + solution(1) + solution(0) = 1 + 0 + 1 + 1 + 0 = 3 반환
# ... 계속 반복

# %%
# 1. 재귀알고리즘 사용
def solution(x):
    # x가 2보다 작을때(0또는 1일 때는 해당 값을 반환함)
    if x < 2:
        return x
    else:
        return solution(x-1) + solution(x-2) 

test = solution(7)
print(test)
# Out:
# 13

# %%
# 2. iterative 사용 -> 반복학습하자..! 어렵다 ㅜㅜ
def solution(x):
    a, b = 0, 1
    for i in range(0, x):
        a, b = b, a + b
    return a 

test = solution(7)
print(test)
# Out:
# 13

# %% [markdown]
# # 7강 - 연결리스트 순회 구현하기

# %%
class Node:
    # 노드안에 있는 데이터와 링크가 가르키는 것 없음!
    def __init__(self, item):
        self.data = item
        # 이동할 다음 노드 가리키는 링크
        self.next = None

class LinkedList:
    # 생성 시 노드 개수는 0임, head와 tail도 None임
    def __init__(self):
        self.nodeCount = 0
        self.head = None
        self.tail = None
    # 다른 노드로 가는 메서드
    # pos번째 노드 자체를 리턴하려는 것
    def getAt(self, pos):
        # 0번째 노드이거나 노드 번째수가 노드 개수보다 클 때 None
        if pos < 1 or pos > self.nodeCount:
            return None
        # 첫번째 노드
        i = 1
        # 첫 번째 리스트를 curr(현재 리스트)로 설정
        curr = self.head
        # i가 pos번째 보다 작은 값이면 무한 반복
        while i < pos:
            # Node 클래스에 있는 self.next 이용
            curr = curr.next
            # 첫 번째 노드에서 1씩 증가한 번째 노드로 이동
            i += 1
        # 마지막에 있는 노드 반환
        return curr

    def traverse(self):
        node_lst = []
        # 빈 연결 리스트에 대한 순회 결과
        if self.head == None:
            return []
        # 처음 노드를 head로 설정
        curr = self.head
        # 처음 노드의 data를 리스트에 첨가
        node_lst.append(curr.data)
        
        # 노드가 1개 이상 있는 연결 리스트에 대한 순회 결과
        while curr.next is not None:
            curr = curr.next
            node_lst.append(curr.data)
        return node_lst

# %%
##### 남이 푼 풀이 ######

# head,tail이 가르키는 것은 데이터+링크를 포함하고 있는 '노드'! 따라서 self.head, self.tail에는 Node class의 인스턴스를 담고 있으므로
# Node 클래스의 data, next에 접근 가능함!
# next(링크)를 타고 다음 노드로 넘어감!

class Node:
    def __init__(self, item):
        # 노드안에 있는 데이터
        self.data = item
        # 다음으로 이동할 노드를 가리키는 링크
        self.next = None

class LinkedList:
    def __init__(self):
        # 노드 개수
        self.nodeCount = 0
        # 첫 노드를 가리킴
        self.head = None
        # 끝 노드를 가리킴
        self.tail = None
    # pos = '몇' 번째 노드인가
    def getAt(self, pos):
        # 노드는 1번째부터 시작하므로 pos=0인자로 넣는건 None을 반환
        if pos < 1 or pos > self.nodeCount:
            return None
        # 찾으러갈 때 한번만 순회하면서 가도록 하기 위한 조건(i<pos)을 달기 위해 정의
        i = 1
        # 현재 노드 : head노드로 시작!
        curr = self.head
        # 1)pos=1일때, i=1이기 때문에 while문 돌지않고 curr을 return
        # 2)pos=2일때, i=1<pos=2이기 때문에 다음노드로 이동할 링크 할당한 후 i+1 시키기! 그러면 i=2가 되고 i<pos만족하지 못하고 curr을 return 함!
        while i < pos:
            curr = curr.next
            i += 1
        return curr

    def traverse(self):
        # 데이터 담을 빈 리스트 정의
        link_lst = []
        # 첫 번째 노드 정의
        node = self.head
        # head 노드가 빈리스트가 아니라면!
        while node is not None:
            # 그 노드에 있는 데이터 담기!
            link_lst.append(node.data)
            # next를 이용해 다음 노드로 이동!
            node = node.next
        return link_lst
        
# 이 solution 함수는 그대로 두어야 합니다.
def solution(x):
    return 0

# %% [markdown]
# # 8강 - 연결리스트 삽입

# %%
def insertAt(self, pos, newNode):
    # pos가 올바른 값을 갖는 범위에 있는지 검사하기 위함
    if pos < 1 or pos > self.nodeCount + 1:
        return False
    # 리스트 맨 앞에다가 새로운 노드를 삽입하는 경우
    if pos == 1:
        # 삽입된 새로운 노드의 링크를 원래 맨앞에 있던 head 노드에다가 연결
        newNode.next = self.head
        # 그리고 새로운 head를 맨 앞에 삽인된 newNode에다가 설정
        self.head = newNode
    # 리스트 중간에다가 새로운 노드를 삽입하는 경우    
    else:
        # pos번째 바로 이전인 prev 노드를 찾자
        prev = self.getAt(pos - 1)
        # 중간에 삽입된 새로운 노드의 링크를 prev의 다음 노드에다가 연결
        newNode.next = prev.next
        # prev의 링크를 새롭게 삽입된 노드에다가 연결
        prev.next = newNode
    # 리스트 맨 뒤에다가 새로운 노드를 삽입하는 경우
    if pos == self.nodeCount + 1:
        # 원래의 tail을 새롭게 삽입된 노드로 설정
        self.tail = newNode
    ## 참고로 빈 리스트에다가 최초로 노드를 삽입하는 경우
    # 리스트 맨 앞, 맨 뒤에 삽입하는 2개 조건을 동시에 만족하면서 heed, tail잘 조정
    
    #마지막으로 새로운 노드를 삽입했으니 nodeCount를 1개 증가
    self.nodeCount += 1
    return True

# %%
def insertAt(self, pos, newNode):
    # pos가 올바른 값을 갖는 범위에 있는지 검사하기 위함
    if pos < 1 or pos > self.nodeCount + 1:
        return False
    # 리스트 맨 앞에다가 새로운 노드를 삽입하는 경우
    if pos == 1:
        # 삽입된 새로운 노드의 링크를 원래 맨앞에 있던 head 노드에다가 연결
        newNode.next = self.head
        # 그리고 새로운 head를 맨 앞에 삽인된 newNode에다가 설정
        self.head = newNode
    # 리스트 중간에다가 새로운 노드를 삽입하는 경우    
    else:
        ##### 달라진 부분-맨 뒤 리스트에 삽입하는 경우 앞에서부터 찾지 않고 바로 tail로 가서 즉시 삽입!
        if pos == self.nodeCount + 1:
            # prev노드는 tail의 노드로 할당
            prev = self.tail
        else:
            # pos번째 바로 이전인 prev 노드를 찾자
            prev = self.getAt(pos - 1)
        # 중간에 삽입된 새로운 노드의 링크를 prev의 다음 노드에다가 연결
        newNode.next = prev.next
        # prev의 링크를 새롭게 삽입된 노드에다가 연결
        prev.next = newNode
    
    ## 참고로 빈 리스트에다가 최초로 노드를 삽입하는 경우
    # 리스트 맨 앞, 맨 뒤에 삽입하는 2개 조건을 동시에 만족하면서 heed, tail잘 조정
    
    #마지막으로 새로운 노드를 삽입했으니 nodeCount를 1개 증가
    self.nodeCount += 1
    return True

# %% [markdown]
# # 9강 -연결리스트 삭제

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.next = None


class LinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = None
        self.head.next = self.tail


    def traverse(self):
        result = []
        curr = self.head
        while curr.next:
            curr = curr.next
            result.append(curr.data)
        return result


    def getAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            return None

        i = 0
        curr = self.head
        while i < pos:
            curr = curr.next
            i += 1

        return curr


    def insertAfter(self, prev, newNode):
        newNode.next = prev.next
        if prev.next is None:
            self.tail = newNode
        prev.next = newNode
        self.nodeCount += 1
        return True


    def insertAt(self, pos, newNode):
        if pos < 1 or pos > self.nodeCount + 1:
            return False

        if pos != 1 and pos == self.nodeCount + 1:
            prev = self.tail
        else:
            prev = self.getAt(pos - 1)
        return self.insertAfter(prev, newNode)

    def popAfter(self, prev):
        # prev가 마지막 노드를 지정하게 되면 None
        if prev == self.nodeCount:
            return None
        # 삭제할 curr 노드 지정
        curr = prev.next
        # curr이 마지막 노드일 때
        if curr.next == None:
            prev.next = None
            self.tail = prev
        # curr이 더미노드 다음 노드부터 마지막 이전 노드 중 하나일 때
        else:
            prev.next = curr.next
        self.nodeCount -= 1
        return curr.data

    def popAt(self, pos):
        if pos < 1 or pos > self.nodeCount:
            raise IndexError
        # popAfter을 이용하기 위해 이전 노드 찾기
        prev = self.getAt(pos-1)
        return self.popAfter(prev)
             
def solution(x):
    return 0

# %% [markdown]
# # 10강 - 양방향 연결 리스트
#
# ## 역방향 순회

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.prev = None
        self.next = None


class DoublyLinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = Node(None)
        self.head.prev = None
        self.head.next = self.tail
        self.tail.prev = self.head
        self.tail.next = None


    def reverse(self):
        data = []
        curr = self.tail
        while curr.prev.prev:
            # curr의 이전 노드 prev로 이동
            prev = curr.prev
            # 이전 노드인 prev의 데이터 담기
            data.append(prev.data)
            # 이전 노드인 prev를 curr노드로 업데이트
            curr = prev
        return data

    def getAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            return None

        if pos > self.nodeCount // 2:
            i = 0
            curr = self.tail
            while i < self.nodeCount - pos + 1:
                curr = curr.prev
                i += 1
        else:
            i = 0
            curr = self.head
            while i < pos:
                curr = curr.next
                i += 1

        return curr


    def insertAfter(self, prev, newNode):
        next = prev.next
        newNode.prev = prev
        newNode.next = next
        prev.next = newNode
        next.prev = newNode
        self.nodeCount += 1
        return True


    def insertAt(self, pos, newNode):
        if pos < 1 or pos > self.nodeCount + 1:
            return False

        prev = self.getAt(pos - 1)
        return self.insertAfter(prev, newNode)


def solution(x):
    return 0

# %% [markdown]
# ## 노드 삽입

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.prev = None
        self.next = None


class DoublyLinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = Node(None)
        self.head.prev = None
        self.head.next = self.tail
        self.tail.prev = self.head
        self.tail.next = None


    def traverse(self):
        result = []
        curr = self.head
        while curr.next.next:
            curr = curr.next
            result.append(curr.data)
        return result


    def insertBefore(self, next, newNode):
        # 기존의 prev노드를 우선 지정(for prev다음에 newNode가 삽입될 것이기 때문)
        prev = next.prev
        # newNode의 이전노드를 우선 설정
        newNode.prev = prev
        # newNode의 다음노드를 우선 설정
        newNode.next = next
        # 기존 prev노드와 next노드간의 연결 해제 후 newNode랑 연결
        prev.next = newNode
        next.prev = newNode
        self.nodeCount += 1
        return True
    
def solution(x):
    return 0

# %% [markdown]
# ## 노드 삭제(popAfter, popBefore, popAt)

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.prev = None
        self.next = None


class DoublyLinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = Node(None)
        self.head.prev = None
        self.head.next = self.tail
        self.tail.prev = self.head
        self.tail.next = None


    def traverse(self):
        result = []
        curr = self.head
        while curr.next.next:
            curr = curr.next
            result.append(curr.data)
        return result


    def getAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            return None

        if pos > self.nodeCount // 2:
            i = 0
            curr = self.tail
            while i < self.nodeCount - pos + 1:
                curr = curr.prev
                i += 1
        else:
            i = 0
            curr = self.head
            while i < pos:
                curr = curr.next
                i += 1

        return curr


    def insertAfter(self, prev, newNode):
        next = prev.next
        newNode.prev = prev
        newNode.next = next
        prev.next = newNode
        next.prev = newNode
        self.nodeCount += 1
        return True


    def insertAt(self, pos, newNode):
        if pos < 1 or pos > self.nodeCount + 1:
            return False

        prev = self.getAt(pos - 1)
        return self.insertAfter(prev, newNode)


    def popAfter(self, prev):
        ### 더미 노드들만 있을 경우 ###
        if self.head == self.tail:
            return None
        ### 삭제할 노드가 중간에 있을 경우 ###
        # next노드 지정
        next = prev.next.next
        # 삭제할 curr노드 지정
        curr = prev.next
        # prev -> next 노드 연결
        prev.next = next
        # next -> prev 노드 연결
        next.prev = prev
        self.nodeCount -= 1
        return curr.data
        
    def popBefore(self, next):
        ### 더미 노드들만 있을 경우 ###
        if self.head == self.tail:
            return None
        ### 삭제할 노드가 중간에 있을 경우 ###
        # next와 연결할 prev노드 지정
        prev = next.prev.prev
        # 삭제할 curr노드 지정
        curr = next.prev
        # next -> prev 노드 연결
        next.prev = prev
        # prev -> next 노드 연결
        prev.next = next
        self.nodeCount -= 1
        return curr.data

    def popAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            raise IndexError
        # 뒷부분의 노드를 삭제하는 경우 -> 어차피 getAt에서 //2 가 들어가서 뒷부분으로 먼저 접근하기 때문에 여기서 굳이 사용해줄 필요는 없다.
        if pos > self.nodeCount // 2:
            prev = self.getAt(pos-1)
            return self.popAfter(prev)
        else:
            next = self.getAt(pos+1)
            return self.popBefore(next)
    # popAt 다른 사람의 풀이(popAfter만 사용했을 떄)
    def popAt(self, pos):
        if pos < 1 or pos > self.nodeCount :
            raise IndexError

        prev = self.getAt(pos - 1)
        curr=self.popAfter(prev)
        return curr
            
def solution(x):
    return 0

# %% [markdown]
# ## 2개 양방향 연결 리스트 병합

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.prev = None
        self.next = None


class DoublyLinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = Node(None)
        self.head.prev = None
        self.head.next = self.tail
        self.tail.prev = self.head
        self.tail.next = None

    # L : 문제에서 L2. 즉, 병합할 양방향 연결리스트
    def concat(self, L):
        ### L이 빈 리스트일 경우
        if L.nodeCount == 0:
            return True
        # self의 tail의 이전노드 지정
        self_end = self.tail.prev
        # L의 head의 다음노드 지정
        L_start = L.head.next
        # 위 두 노드를 연결해 병합
        self_end.next = L_start
        L_start.prev = self_end
        # 병합된 리스트들의 tail 재지정
        self.tail = L.tail
        self.nodeCount = self.nodeCount + L.nodeCount
        return True
        
    def traverse(self):
        result = []
        curr = self.head
        while curr.next.next:
            curr = curr.next
            result.append(curr.data)
        return result

    
    def getAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            return None

        if pos > self.nodeCount // 2:
            i = 0
            curr = self.tail
            while i < self.nodeCount - pos + 1:
                curr = curr.prev
                i += 1
        else:
            i = 0
            curr = self.head
            while i < pos:
                curr = curr.next
                i += 1

        return curr


    def insertAfter(self, prev, newNode):
        next = prev.next
        newNode.prev = prev
        newNode.next = next
        prev.next = newNode
        next.prev = newNode
        self.nodeCount += 1
        return True


    def insertAt(self, pos, newNode):
        if pos < 1 or pos > self.nodeCount + 1:
            return False

        prev = self.getAt(pos - 1)
        return self.insertAfter(prev, newNode)


def solution(x):
    return 0

# %% [markdown]
# # 12강 - 스택 응용

# %%
class ArrayStack:

    def __init__(self):
        self.data = []

    def size(self):
        return len(self.data)

    def isEmpty(self):
        return self.size() == 0

    def push(self, item):
        self.data.append(item)

    def pop(self):
        return self.data.pop()

    def peek(self):
        return self.data[-1]

prec = {
    '*': 3, '/': 3,
    '+': 2, '-': 2,
    '(': 1
}

def solution(S):
    opStack = ArrayStack()
    answer = ''
    # 문자열 S의 한 글자씩 loop
    for c in S:
        # 피연산자일 경우
        if c not in '+-*/()':
            answer += str(c)
        # c가 '('일 경우
        elif c == '(':
            opStack.push(c)
        # c가 일반 연산자일 경우
        elif c in prec:
            # 우선 스택이 비어있으면 push
            if opStack.size() == 0:
                opStack.push(c)
            # 기존 스택에 데이터가 있는데 맨위가 '('이라면
            elif opStack.peek() == '(':
                opStack.push(c)
            # 마주친 연산자가 스택 안에 있는 연산자와 우선순위 조정하는 경우
            # 마주친 연산자 순위 <= 스택에 이미 들어있는 연산자 순위
            elif prec[opStack.peek()] >= prec[c]:
                # 스택에 이미 들어있는 연산자가 여러개일 경우, 마주친 연산자 순위와 계속 비교 ****
                while prec[opStack.peek()] >= prec[c]:
                    # 스택에 이미 있는 연산자를 모두 pop
                    answer += str(opStack.pop())
                    # 스택에 있는 모든 연산자 다 꺼냈을 경우
                    if opStack.isEmpty():
                        opStack.push(c)
                        break
            # 마주친 연산자 순위 > 스택에 이미 들어있는 연산자 순위
            elif prec[opStack.peek()] < prec[c]:
                # 마주친 연산자를 스택에 넣기
                opStack.push(c)
        # c가 ')'일 경우
        elif c == ')':
            # 스택에 있는 상위 데아터하나씩 보면서 '('가 나올때까지 모두 pop
            while opStack.peek() != '(':
                answer += opStack.pop()
            # 스택에 남아있는 '('처리
            opStack.pop()
    # 스택이 빌 때까지 모두 pop시키기
    while not opStack.isEmpty():
        answer += opStack.pop()
            
    return answer

# %% [markdown]
# ## 다른사람 풀이1

# %%
def solution(S):
    opStack = ArrayStack()
    answer = ''
    for x in S:
        if x in prec:
            if x == '(' or opStack.isEmpty():
                pass
            else:
                if prec[x] <= prec[opStack.peek()]:
                    answer += opStack.pop()
            opStack.push(x)
        elif x == ')':
            while opStack.peek() != '(':
                answer += opStack.pop()
            opStack.pop()
        else:
            answer += x
    while not opStack.isEmpty():
        answer += opStack.pop()
    return answer

# %% [markdown]
# ## 다른사람 풀이2

# %%
def solution(S):
    answer = ''
    opStack = ArrayStack()
    for char in S:
        if char in prec:
            if opStack.isEmpty():
                opStack.push(char)
            elif char == '(':
                opStack.push(char)
            elif prec[char] > prec[opStack.peek()]:
                opStack.push(char)
            elif prec[char] <= prec[opStack.peek()]:
                answer += opStack.pop()
                opStack.push(char)
            else:
                opStack.push(char)
        elif char == ')':
            while opStack.peek() != '(':
                answer += opStack.pop()
            opStack.pop()
        else:            
            answer += char
    while opStack.isEmpty() == False:
        answer += opStack.pop()
    return answer

# %% [markdown]
# - 연습1

# %%
def solution(S):
    opStack = ArrayStack()
    answer = ''
    # 문자열 S의 한 글자씩 loop
    for c in S:
        # c가 prec 중 하나일 때
        if c in prec:
            # 스택이 빈 상태이거나 c == '('일 때
            if opStack.isEmpty() or c == '(':
                opStack.push(c)
            # 마주친 연산자와 스택에 있는 맨 위 연산자와 우선순위 조정
            elif prec[c] <= prec[opStack.peek()]:
                while prec[c] <= prec[opStack.peek()]:
                    answer += opStack.pop()
                    if opStack.isEmpty():
                        opStack.push(c)
                        break
            else:
                opStack.push(c)
        # c == ')'일 때
        elif c == ')':
            while opStack.peek() != '(':
                answer += opStack.pop()
            # 스택에 남아있는 '('처리
            opStack.pop()
        # c가 피연산자일 때
        else:
            answer += c
    while not opStack.isEmpty():
        answer += opStack.pop()
    
    return answer

# %% [markdown]
# - 연습2

# %%
def solution(S):
    opStack = ArrayStack()
    answer = ''
    # 문자열 S의 한 글자씩 loop
    for char in S:
        if char in prec:
            if opStack.isEmpty() or char == '(':
                opStack.push(char)
            elif prec[char] <= prec[opStack.peek()]:
                while prec[char] <= prec[opStack.peek()]:
                    answer += opStack.pop()
                    if opStack.isEmpty():
                        opStack.push(char)
                        break
            else:
                opStack.push(char)
        elif char == ')':
            while opStack.peek() != '(':
                answer += opStack.pop()
            # '('처리
            opStack.pop()
        else:
            answer += char
    # 스택에 데이터 남아있는지 최종 확인
    while not opStack.isEmpty():
        answer += opStack.pop()
    return answer

# %% [markdown]
# # 13강 - 스택응용 - 중위표현식->후위표현식->후위표현식 계산

# %%
class ArrayStack:

    def __init__(self):
        self.data = []

    def size(self):
        return len(self.data)

    def isEmpty(self):
        return self.size() == 0

    def push(self, item):
        self.data.append(item)

    def pop(self):
        return self.data.pop()

    def peek(self):
        return self.data[-1]


def splitTokens(exprStr):
    tokens = []
    val = 0
    valProcessing = False
    for c in exprStr:
        if c == ' ':
            continue
        if c in '0123456789':
            val = val * 10 + int(c)
            valProcessing = True
        else:
            if valProcessing:
                tokens.append(val)
                val = 0
            valProcessing = False
            tokens.append(c)
    if valProcessing:
        tokens.append(val)

    return tokens


def infixToPostfix(tokenList):
    prec = {
        '*': 3,
        '/': 3,
        '+': 2,
        '-': 2,
        '(': 1,
    }
    opStack = ArrayStack()
    postfixList = []
    # token 하나씩 loop
    for token in tokenList:
        # token이 prec안에 있을 때
        if token in prec:
            # 스택이 비어있거나 token='('일 때
            if opStack.isEmpty() or token == '(':
                opStack.push(token)
            # 마주친 연산자의 순위 <= 스택 상위의 연산자 순위
            elif prec[token] <= prec[opStack.peek()]:
                while prec[token] <= prec[opStack.peek()]:
                    postfixList.append(opStack.pop())
                    if opStack.isEmpty():
                        opStack.push(token)
                        break
            # 마주친 연산자의 순위 > 스택 상위의 연산자 순위
            else:
                opStack.push(token)
        # token = ')'일 때
        elif token == ')':
            # 스택 peek 데이터가 '('일 때까지 pop
            while opStack.peek() != '(':
                postfixList.append(opStack.pop())
            # '('연산자 pop처리
            opStack.pop()
        # token이 피연산자일 때 
        else:
            postfixList.append(token)
        # 스택이 비어있는지 확인
    while not opStack.isEmpty():
        postfixList.append(opStack.pop())

    return postfixList


def postfixEval(tokenList):
    opStack = ArrayStack()
    prec = ['*','/','+','-']
    # token 하나씩 loop
    for token in tokenList:
        # token in prec
        if token in prec:
            # token == *
            if token == '*':
                two_peek = opStack.pop()
                one_peek = opStack.pop()
                result = one_peek * two_peek
                opStack.push(result)
            # token == +
            elif token == '+':
                two_peek = opStack.pop()
                one_peek = opStack.pop()
                result = one_peek + two_peek
                opStack.push(result)
            # token == -
            elif token == '-':
                two_peek = opStack.pop()
                one_peek = opStack.pop()
                result = one_peek - two_peek
                opStack.push(result)
            # token == /
            else:
                two_peek = opStack.pop()
                one_peek = opStack.pop()
                result = one_peek / two_peek
                opStack.push(result)
        # token이 숫자일 때, 스택에 push
        else:
            opStack.push(token)
    if opStack.size() == 1:
        return opStack.pop()

def solution(expr):
    tokens = splitTokens(expr)
    postfix = infixToPostfix(tokens)
    val = postfixEval(postfix)
    return val

# %% [markdown]
# # 15강 - 환형 큐 구현
#
# - ``%`` : ex) 1 % 4 = 1(``나머지``)
# - ``%``를 이용해서 끝 인덱스를 만나면 처음 인덱스로 돌아가는 기능 구현 가능!!

# %%
class CircularQueue:

    def __init__(self, n):
        self.maxCount = n
        self.data = [None] * n
        self.count = 0
        self.front = -1
        self.rear = -1


    def size(self):
        return self.count

    def isEmpty(self):
        return self.count == 0

    def isFull(self):
        return self.count == self.maxCount

    def enqueue(self, x):
        if self.isFull():
            raise IndexError('Queue full')
        self.rear = (self.rear+1)%self.maxCount
        self.data[self.rear] = x
        self.count += 1

    def dequeue(self):
        if self.isEmpty():
            raise IndexError('Queue empty')
        self.front = (self.front+1)%self.maxCount
        x = self.data[self.front]
        self.count -= 1
        return x

    def peek(self):
        if self.isEmpty():
            raise IndexError('Queue empty')
        return self.data[(self.front+1)%self.maxCount]


def solution(x):
    return 0

# %% [markdown]
# ``lambda`` 이용한 구현

# %%
class CircularQueue:

    def __init__(self, n):
        self.maxCount = n
        self.data = [None] * n
        self.count = 0
        self.front = -1
        self.rear = -1


    def size(self):
        return self.count

    def isEmpty(self):
        return self.count == 0

    def isFull(self):
        return self.count == self.maxCount

    def enqueue(self, x):
        if self.isFull():
            raise IndexError('Queue full')
        self.rear = (lambda z: 0 if z+1 > self.maxCount-1 else z+1)(self.rear)
        self.data[self.rear] = x
        self.count += 1

    def dequeue(self):
        if self.isEmpty():
            raise IndexError('Queue empty')
        self.front = (lambda z: 0 if z+1 > self.maxCount-1 else z+1)(self.front)
        x = self.data[self.front]
        self.count -= 1
        return x

    def peek(self):
        if self.isEmpty():
            raise IndexError('Queue empty')
        return self.data[(lambda z: 0 if z+1 > self.maxCount-1 else z+1)(self.front)]


def solution(x):
    return 0

# %% [markdown]
# # 16강 - 우선순위 큐 연산 구현
#
# - 반복..

# %%
class Node:

    def __init__(self, item):
        self.data = item
        self.prev = None
        self.next = None


class DoublyLinkedList:

    def __init__(self):
        self.nodeCount = 0
        self.head = Node(None)
        self.tail = Node(None)
        self.head.prev = None
        self.head.next = self.tail
        self.tail.prev = self.head
        self.tail.next = None


    def __repr__(self):
        if self.nodeCount == 0:
            return 'LinkedList: empty'

        s = ''
        curr = self.head
        while curr.next.next:
            curr = curr.next
            s += repr(curr.data)
            if curr.next.next is not None:
                s += ' -> '
        return s


    def getLength(self):
        return self.nodeCount


    def traverse(self):
        result = []
        curr = self.head
        while curr.next.next:
            curr = curr.next
            result.append(curr.data)
        return result


    def reverse(self):
        result = []
        curr = self.tail
        while curr.prev.prev:
            curr = curr.prev
            result.append(curr.data)
        return result


    def getAt(self, pos):
        if pos < 0 or pos > self.nodeCount:
            return None

        if pos > self.nodeCount // 2:
            i = 0
            curr = self.tail
            while i < self.nodeCount - pos + 1:
                curr = curr.prev
                i += 1
        else:
            i = 0
            curr = self.head
            while i < pos:
                curr = curr.next
                i += 1

        return curr


    def insertAfter(self, prev, newNode):
        next = prev.next
        newNode.prev = prev
        newNode.next = next
        prev.next = newNode
        next.prev = newNode
        self.nodeCount += 1
        return True


    def insertAt(self, pos, newNode):
        if pos < 1 or pos > self.nodeCount + 1:
            return False

        prev = self.getAt(pos - 1)
        return self.insertAfter(prev, newNode)


    def popAfter(self, prev):
        curr = prev.next
        next = curr.next
        prev.next = next
        next.prev = prev
        self.nodeCount -= 1
        return curr.data


    def popAt(self, pos):
        if pos < 1 or pos > self.nodeCount:
            return None

        prev = self.getAt(pos - 1)
        return self.popAfter(prev)


    def concat(self, L):
        self.tail.prev.next = L.head.next
        L.head.next.prev = self.tail.prev
        self.tail = L.tail

        self.nodeCount += L.nodeCount


class PriorityQueue:

    def __init__(self):
        self.queue = DoublyLinkedList()


    def size(self):
        return self.queue.getLength()

    def isEmpty(self):
        return self.size() == 0

    def enqueue(self, x):
        newNode = Node(x)
        curr = self.queue.head
        while curr.next.data != None and x < curr.next.data:
            curr = curr.next
        # insetAt은 사용 부적절. 왜냐하면 그 사잇값에 넣을려면 런타임에러
        return self.queue.insertAfter(curr, newNode)
        
    def dequeue(self):
        return self.queue.popAt(self.queue.getLength())

    def peek(self):
        return self.queue.getAt(self.queue.getLength()).data


def solution(x):
    return 0
