# %%
import requests
url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=70chvGVOwguGdjPrpZL063fX50H6oufjCGWQ77SQ2AL0mOHl9nzn58ipR1dB5G0rjNmt7Xhj%2FZ3pPAXRBOq5Ig%3D%3D&numOfRows=50&pageNo=1&dataCd=ASOS&dateCd=DAY&startDt=20010205&endDt=20181230&stnIds=108'
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.content, 'html.parser')
print(soup)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response><header><resultcode>00</resultcode><resultmsg>NORMAL_SERVICE</resultmsg></header><body><datatype>XML</datatype><items><item><stnid>108</stnid><tm>2001-02-05</tm><avgta>1.5</avgta><minta>-2.1</minta><mintahrmt>620</mintahrmt><maxta>5.7</maxta><maxtahrmt>1453</maxtahrmt><mi10maxrnhrmt>0</mi10maxrnhrmt><hr1maxrn>0.0</hr1maxrn><hr1maxrnhrmt>0</hr1maxrnhrmt><sumrn>0.0</sumrn><maxinsws>6.5</maxinsws><maxinswswd>270</maxinswswd><maxinswshrmt>1341</maxinswshrmt><maxws>4.0</maxws><maxwswd>270</maxwswd><maxwshrmt>1350</maxwshrmt><avgws>1.4</avgws><hr24sumrws>1210</hr24sumrws><maxwd>290</maxwd><avgtd>-3.4</avgtd><minrhm>58</minrhm><minrhmhrmt>1757</minrhmhrmt><avgrhm>68.0</avgrhm><avgpv>4.8</avgpv><avgpa>1012.4</avgpa><maxps>1027.0</maxps><maxpshrmt>839</maxpshrmt><minps>1019.7</minps><minpshrmt>1731</minpshrmt><avgps>1023.4</avgps><ssdur>10.5</ssdur><sumsshr>4.3</sumsshr><hr1maxicsrhrmt>1300</hr1maxicsrhrmt><hr1maxicsr>1.5</hr1maxicsr><sumgsr>8.9</sumgsr><ddmefs>0.0</ddmefs><ddmefshrmt>0</ddmefshrmt><ddmes>6.5</ddmes><ddmeshrmt>0</ddmeshrmt><sumdpthfhsc>0.0</sumdpthfhsc><avgtca>2.3</avgtca><avglmac>0.8</avglmac><avgts>0.4</avgts><mintg>-5.9</mintg><avgcm5te>-0.6</avgcm5te><avgcm10te>-0.6</avgcm10te><avgcm20te>-0.5</avgcm20te><avgcm30te>-0.1</avgcm30te><avgm05te>1.1</avgm05te><avgm10te>3.7</avgm10te><avgm15te>6.8</avgm15te><avgm30te>12.0</avgm30te><avgm50te>14.8</avgm50te><sumlrgev>0.0</sumlrgev><sumsmlev>1.4</sumsmlev><n99rn>0.0</n99rn><iscs>-{박무}-{박무}{강도0}0300-{박무}{강도0}0600-{박무}{강도1}0900-{박무}{강도0}1200-{박무}{강도1}1500-{박무}{강도0}1800-{박무}{강도0}2100-{박무}{강도0}2400-</iscs><sumfogdur>0.0</sumfogdur></item><item><stnid>108</stnid><tm>2001-02-06</tm><avgta>2.6</avgta><minta>-0.7</minta><mintahrmt>733</mintahrmt><maxta>6.3</maxta><maxtahrmt>1429</maxtahrmt><mi10maxrnhrmt>0</mi10maxrnhrmt><hr1maxrn>0.0</hr1maxrn><hr1maxrnhrmt>0</hr1maxrnhrmt><sumrn>0.0</sumrn><maxinsws>6.3</maxinsws><
= 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=70chvGVOwguGdjPrpZL063fX50H6oufjCGWQ77SQ2AL0mOHl9nzn58ipR1dB5G0rjNmt7Xhj%2FZ3pPAXRBOq5Ig%3D%3D'


for page in range(1,132):
    uri = url+"&numOfRows=50"+f"&pageNo={page}"+"&dataCd=ASOS"+"&dateCd=DAY&startDt=20010205&endDt=20181230&stnIds=108"
    res = requests.get(uri)
    time.sleep(3)
    soup = bs(res.content, 'html.parser')
    items = soup.select('item')
    # Attribute마다 담을 빈 리스트 할당
    date_lst = []
    avg_ta_lst = []
    max_ta_lst = []
    min_ta_lst = []
    sum_rn_lst = []
    sum_sshr_lst = []
    max_insws_lst = []
    max_ws_lst = []
    sum_gsr_lst = []
    avg_ts_lst = []
    min_rhm_lst = []
    avg_rhm_lst = []
    avg_ws_lst = []
    gr1_maxicsr_lst = []
    for item in items:
        date = item.select_one('tm').text
        avg_ta = item.select_one('avgta').text
        max_ta = item.select_one('maxta').text
        min_ta = item.select_one('minta').text
        sum_rn = item.select_one('sum_rn')
        if sum_rn is None:
            sum_rn = 0
        else:
            sum_rn = sum_rn.text
        sum_sshr = item.select_one('sumsshr').text
        max_insws = item.select_one('maxinsws').text
        max_ws = item.select_one('maxws').text
        sum_gsr = item.select_one('sumgsr').text
        avg_ts = item.select_one('avg_ts')
        if avg_ts is None:
            avg_ts = 0
        else :
            avg_ts = avg_ts.text
        min_rhm = item.select_one('minrhm').text
        avg_rhm = item.select_one('avgrhm').text
        avg_ws = item.select_one('avgws').text
        hr1_maxicsr = item.select_one('hr1maxicsr').text
        
        # 변수명에 맞게 각 리스트에 담기
        date_lst.append(date)
        avg_ta_lst.append(avg_ta)
        max_ta_lst.append(max_ta)
        min_ta_lst.append(min_ta)
        sum_rn_lst.append(sum_rn)
        sum_sshr_lst.append(sum_sshr)
        max_insws_lst.append(max_insws)
        max_ws_lst.append(max_ws)
        sum_gsr_lst.append(sum_gsr)
        avg_ts_lst.append(avg_ts)
        min_rhm_lst.append(min_rhm)
        avg_rhm_lst.append(avg_rhm)
        avg_ws_lst.append(avg_ws)
        gr1_maxicsr_lst.append(gr1_maxicsr)

# %%
print(date_lst)
# Out:
# ['2001-03-27', '2001-03-28', '2001-03-29', '2001-03-30', '2001-03-31', '2001-04-01', '2001-04-02', '2001-04-03', '2001-04-04', '2001-04-05', '2001-04-06', '2001-04-07', '2001-04-08', '2001-04-09', '2001-04-10', '2001-04-11', '2001-04-12', '2001-04-13', '2001-04-14', '2001-04-15', '2001-04-16', '2001-04-17', '2001-04-18', '2001-04-19', '2001-04-20', '2001-04-21', '2001-04-22', '2001-04-23', '2001-04-24', '2001-04-25', '2001-04-26', '2001-04-27', '2001-04-28', '2001-04-29', '2001-04-30', '2001-05-01', '2001-05-02', '2001-05-03', '2001-05-04', '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08', '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12', '2001-05-13', '2001-05-14', '2001-05-15']

# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import datetime

url = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=70chvGVOwguGdjPrpZL063fX50H6oufjCGWQ77SQ2AL0mOHl9nzn58ipR1dB5G0rjNmt7Xhj%2FZ3pPAXRBOq5Ig%3D%3D'

weather_dict = {}
for page in range(1,3):
    uri = url+"&numOfRows=50"+f"&pageNo={page}"+"&dataCd=ASOS"+"&dateCd=DAY&startDt=20010205&endDt=20181230&stnIds=108"
    res = requests.get(uri)
    time.sleep(3)
    soup = bs(res.content, 'html.parser')
    items = soup.select('item')
    
    for item in items:
        date = item.select_one('tm').text
        avg_ta = item.select_one('avgta').text
        max_ta = item.select_one('maxta').text
        min_ta = item.select_one('minta').text
        sum_rn = item.select_one('sum_rn')
        if sum_rn is None:
            sum_rn = 0
        else:
            sum_rn = sum_rn.text
        sum_sshr = item.select_one('sumsshr').text
        max_insws = item.select_one('maxinsws').text
        max_ws = item.select_one('maxws').text
        sum_gsr = item.select_one('sumgsr').text
        avg_ts = item.select_one('avg_ts')
        if avg_ts is None:
            avg_ts = 0
        else :
            avg_ts = avg_ts.text
        min_rhm = item.select_one('minrhm').text
        avg_rhm = item.select_one('avgrhm').text
        avg_ws = item.select_one('avgws').text
        hr1_maxicsr = item.select_one('hr1maxicsr').text
        
        weather_dict['주간날짜'] = date
    print(weather_dict)
# Out:
# {'주간날짜': '2001-03-26'}
# {'주간날짜': '2001-05-15'}

# %%
# 데이터 DB에 담기
import pymysql
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='watson1259@', db='weather',charset='utf8')
cursor = db.cursor()

sql = """insert into weather(date) values("""+weather_dict['주간날짜']+""")"""
'''
sql = """INERT INTO weather VALUES('"""+weather_dict['주간날짜']+"""','"""+weather_dict['최고기온']+"""',
'"""+weather_dict['최저기온']+"""','"""+weather_dict['일강수량']+"""','"""+weather_dict['합계일조시간']+"""',
'"""+weather_dict['최대순간풍속']+"""','"""+weather_dict['최대풍속']+"""',
'"""+weather_dict['합계일사']+"""','"""+weather_dict['평균지면온도']+"""',
'"""+weather_dict['최소상대습도']+"""','"""+weather_dict['평균상대습도']+"""',
'"""+weather_dict['1시간최다일사량']+"""','"""+weather_dict['평균풍속']+"""');"""
'''
cursor.execute(sql)
db.commit()
db.close()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-14-eb0f43589d26> in <module>
#      13 '"""+weather_dict['1시간최다일사량']+"""','"""+weather_dict['평균풍속']+"""');"""
#      14 '''
# ---> 15 cursor.execute(sql)
#      16 db.commit()
#      17 db.close()
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\users\joyh1\anaconda3\envs\venvforpython\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1292, "Incorrect datetime value: '1990' for column 'date' at row 1")

# %%
# 내 MySQL 서버에 담아볼 table 만들기
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='watson1259@', db='weather',charset='utf8')
cursor = db.cursor()
sql ="""
    create table weather_2(
        date varchar(10) not null primary key,
        최고기온 float not null,
        최저기온 float not null,
        일강수량 float not null,
        합계일조시간 float not null,
        최대순간풍속 float not null,
        최대풍속 float not null,
        합계일사 float not null,
        평균지면온도 float not null,
        최소상대습도 float not null,
        평균상대습도 float not null,
        평균풍속 float not null,
        1시간최다일사량 float not null
);
"""
cursor.execute(sql)
db.commit()
db.cursor()
